# %%
import urllib.request
print("Enter the website: ")
site=input()
response =  urllib.request.urlopen(str(site))
html = response.read()
# Out:
# Enter the website:
#  https://en.wikipedia.org/wiki/RNA

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'html5lib')
text = soup.get_text(strip = True)

# %%
import nltk
tokens = [t for t in text.split()]
from nltk.corpus import stopwords
sr= stopwords.words('english')
clean_tokens = tokens[:]
for token in tokens:
    if token in stopwords.words('english'):
        
        clean_tokens.remove(token)
freq = nltk.FreqDist(clean_tokens)
v=0
k='Hi'
for key,val in freq.items():
    if val>v:
        v=val
        k=key
print(" This Website is related to " + str(k) + " .The Word Frequency is " + str(v) + "\n")
print(" FREQUENCY DISTRIBUTION OF THE WEBSITE")
freq.plot(20, cumulative=False)
# Out:
#  This Website is related to RNA .The Word Frequency is 112
#
#  FREQUENCY DISTRIBUTION OF THE WEBSITE
